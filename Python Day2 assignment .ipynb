# %% [markdown]
# Rules to define a variable

# %% [markdown]
# 1.A keyword can not be used as a variable 'if','def'and 'for' are the reserved keyword,they can not be used as a variable.
#
# 2.A variable can contains letters(lower case and upper case),numbers,underscore.
#
# 3.Python is a case sensitive and hence variable are also case sensitive.
#
# 4.A variable cannot start with a number.
#
# 5.A variable is assigned to data by using the assignment operator.

# %% [markdown]
# Python assignment statement

# %%
<variable name> = <data>

# %%
x=y=z=10

# %% [markdown]
# Types of Operator

# %% [markdown]
# 1.Airthmatic Operator
#
# 2.Comparision Operator
#
# 3.Assignment Operator
#
# 4.Bitwise Operator
#
# 5.Logical Operator
#
# 6.Membership Operator
#
# 7.Identity Operator

# %% [markdown]
# Airthmatic Operator

# %% [markdown]
# '** ' exponent
#
# '*'   multiplcation
#
# ' /  '  division
#
# %    modulus
#
# '+'   addition
#
# '-'    subtraction
#
#  ' // ' floor divison

# %%
9**9
# Out:
# 387420489

# %%
10*2
# Out:
# 20

# %%
10/2

# %%
20%3
# Out:
# 2

# %%
20//3
# Out:
# 6

# %% [markdown]
# Comparision Operator

# %% [markdown]
# Equal to  =
#
# Not equal to  !=
#
# Less than  <
#
# Greater than  >
#
# Lessthan or equal to  <=
#
# Greaterthan or equal to  >=

# %%
a=10
b=40
c=10

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a>=c
# Out:
# True

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %% [markdown]
# Bitwise operator
#
# |  bitwise OR operation
#
# &  bitwise AND operation
#
# -  bitwise one's complement
#
# ^  bitwise XOR
#
#  >>  binary right shift operator
#
# <<  binary left shift opearator

# %%
a=10
b=20

# %%
a|b
# Out:
# 30

# %%
bin(a)
# Out:
# '0b1010'

# %%
bin(b)
# Out:
# '0b10100'

# %%
bin(a|b)
# Out:
# '0b11110'

# %%
bin(a&b)
# Out:
# '0b0'

# %%
bin(a^b)
# Out:
# '0b11110'

# %%
bin(a>>b)
# Out:
# '0b0'

# %%
bin(a<<b)
# Out:
# '0b101000000000000000000000'

# %% [markdown]
#  Assignment operator
#
# Assignment operators are used in Python to assign values to variables.
# a = 5 is a simple assignment operator that assigns the value 5 on the right to the variable a on the left.
# There are various compound operators in Python like a += 5 that adds to the variable and later assigns the same. It is equivalent to a = a + 5.

# %% [markdown]
# Logical operator
#
# AND - If both side is true ,then the AND operator returns True
#
# OR  - If any side is true , then the OR operator returns True
#
# Not - The operator inverts the outcome of the operator

# %%
x = True
y = False
 
print('x and y is',x and y)
 
print('x or y is',x or y)
 
print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
#  Membership Operator
#
# in and not in are the membership operators in Python. They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).

# %%
 x = 'Hello world'
y = {1:'a',2:'b'}
 
# Output: True
print('H' in x)
 
# Output: True
print('hello' not in x)
 
# Output: True
print(1 in y)
 
# Output: False
print('a' in y)
# Out:
# True
# True
# True
# False

# %% [markdown]
# Identity Operator
#
# is and is not are the identity operators in Python. They are used to check if two values (or variables) are located on the same part of the memory. Two variables that are equal does not imply that they are identical.

# %%
 x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]
 
# Output: False
print(x1 is not y1)
 
# Output: True
print(x2 is y2)
 
# Output: False
print(x3 is y3)
# Out:
# False
# True
# False
